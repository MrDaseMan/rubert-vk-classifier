# %% [markdown]
# ### Установка необходимых пакетов
# Читаем из файла `requirements.txt`
#
# **Библиотеки:**
# * PyTorch v2.1.0
# * Sentencepiece v0.1.99
# * Transformers v4.34.1
# * Pandas  v2.1.1
# * NumPy v1.26.1
# * Scikit Learn v1.3.2

# %%
# %pip install -r requirements.txt

# %% [markdown]
# ### Считываем датасет
#
# Файлы берём из папки `/dataset`
#
# Для обучения - `train.csv`
#
# Для валидации - `validate.csv`
#
# Для тестирования - `test.csv`

# %%
import pandas as pd # Импортируем библиотеку Pandas

# Отключаем предупреждения
no_deprecation_warning=True

# %%
train_data = pd.read_csv('./dataset/train.csv')     # Считываем данные для обучения
valid_data = pd.read_csv('./dataset/validate.csv')  # Считываем данные для валидации

# %% [markdown]
# ### Инициализируем библиотеку BERT (`rubert-tiny`)
#
# Импортируем необходимые модули

# %%
from bert_classifier import BertClassifier  # Импортируем основной класс BertClassifier

# %% [markdown]
# Инициализируем `BertClassifier` на `41` группу и `60` эпох

# %%
classifier = BertClassifier(
    model_path='cointegrated/rubert-tiny',          # Путь до репозитория с дообучаемой моделью
    tokenizer_path='cointegrated/rubert-tiny',      # Путь до токенизатора
    n_classes=41,                                   # Количество классов для обучения
    epochs=60,                                      # Количество эпох обучения
    max_len=1024,                                   # Максимальный размер текста
    model_save_path='./output/model.pt'             # Путь до сохранения модели
)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at cointegrated/rubert-tiny and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ### Подготавливаем данные для обучения и валидации

# %%
classifier.preparation(
    X_train=list(train_data['groups']),             # Обучающие поля таблицы с текстом
    y_train=list(train_data['code']),               # Обучающие поля таблицы с реальными кодами групп
    X_valid=list(valid_data['groups']),             # Валидирующие поля таблицы с текстом
    y_valid=list(valid_data['code'])                # Валидирующие поля таблицы с реальными кодами групп
)
# Out:
# c:\Users\mrdas\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %% [markdown]
# Проверяем возможность обучения нейросети на CUDA ядрах и выводим дополнительную информацию

# %%
import torch
print(f"CUDA поддерживается этой системой: {torch.cuda.is_available()}")
print(f"Версия CUDA: {torch.version.cuda}")
 
# Storing ID of current CUDA device
cuda_id = torch.cuda.current_device()
print(f"ID текущего CUDA устройства: {torch.cuda.current_device()}")
       
print(f"Имя текущего CUDA устройства: {torch.cuda.get_device_name(cuda_id)}")
# Out:
# CUDA поддерживается этой системой: True
# Версия CUDA: 11.8
# ID текущего CUDA устройства: 0
# Имя текущего CUDA устройства: NVIDIA GeForce RTX 4070 Ti

# %% [markdown]
# ### Обучаем нейросеть

# %%
classifier.train()
# Out:
# Эпоха 1/60
# Обучение: потери 3.4729375537012666 | точность 0.06205673758865248
# Валидация: потери 3.391901946836902 | точность 0.08713692946058091
# ----------
# Эпоха 2/60
# Обучение: потери 3.2672960019447435 | точность 0.1427304964539007
# Валидация: потери 3.165799225530317 | точность 0.19294605809128632
# ----------
# Эпоха 3/60
# Обучение: потери 3.006519720587932 | точность 0.2278368794326241
# Валидация: потери 2.9954433902617423 | точность 0.23029045643153526
# ----------
# Эпоха 4/60
# Обучение: потери 2.7837150365533962 | точность 0.2783687943262411
# Валидация: потери 2.9272385951011413 | точность 0.23858921161825727
# ----------
# Эпоха 5/60
# Обучение: потери 2.5900427573163745 | точность 0.33156028368794327
# Валидация: потери 2.845012257176061 | точность 0.26141078838174275
# ----------
# Эпоха 6/60
# Обучение: потери 2.4319404632272854 | точность 0.3670212765957447
# Валидация: потери 2.8227072454267934 | точность 0.27800829875518673
# ----------
# Эпоха 7/60
# Обучение: потери 2.3012352426287155 | точность 0.4157801418439716
# Валидация: потери 2.779091288966517 | точность 0.2863070539419087
# ----------
# Эпоха 8/60
# Обучение: потери 2.1690839159656576 | точность 0.4441489361702128
# Валидация: потери 2.7352316764093216 | точность 0.3008298755186722
# ----------
# Эпоха 9/60
# Обучение: потери 2.0722890924400006 | точность 0.49113475177304966
# Валидация: потери 2.666491708447856 | точность 0.3049792531120332
# ----------
# Эпоха 10/60
# Обучение: потери 1.9823798730339803 | точность 0.5141843971631206
# Валидация: потери 2.670546877768732 | точность 0.3278008298755187
# ----------
# Эпоха 11/60
# Обучение: потери 1.8927536396913125 | точность 0.5292553191489362
# Валидация: потери 2.645838395241768 | точность 0.31950207468879666
# ----------
# Эпоха 12/60
# Обучение: потери 1.8112692900106941 | точность 0.5531914893617021
# Валидация: потери 2.6260333676492014 | точность 0.31950207468879666
# ----------
# Эпоха 13/60
# Обучение: потери 1.7349762513603963 | точность 0.5735815602836879
# Валидация: потери 2.608947284760014 | точность 0.33402489626556015
# ----------
# Эпоха 14/60
# Обучение: потери 1.6711980641727717 | точность 0.5904255319148936
# Валидация: потери 2.5863627387631323 | точность 0.33402489626556015
# ----------
# Эпоха 15/60
# Обучение: потери 1.5761027084269994 | точность 0.6187943262411347
# Валидация: потери 2.6653319058879728 | точность 0.34024896265560167
# ----------
# Эпоха 16/60
# Обучение: потери 1.5336761180783662 | точность 0.6365248226950354
# Валидация: потери 2.677136363521699 | точность 0.34232365145228216
# ----------
# Эпоха 17/60
# Обучение: потери 1.453568908530222 | точность 0.6622340425531915
# Валидация: потери 2.5802924248480026 | точность 0.33402489626556015
# ----------
# Эпоха 18/60
# Обучение: потери 1.4067898166011756 | точность 0.6640070921985816
# Валидация: потери 2.5640630414409022 | точность 0.3360995850622407
# ----------
# Эпоха 19/60
# Обучение: потери 1.3491646462762859 | точность 0.6870567375886525
# Валидация: потери 2.542430258566333 | точность 0.3506224066390041
# ----------
# Эпоха 20/60
# Обучение: потери 1.2983501788596032 | точность 0.7056737588652482
# Валидация: потери 2.5895516257132254 | точность 0.35269709543568467
# ----------
# Эпоха 21/60
# Обучение: потери 1.2448289646229274 | точность 0.7287234042553191
# Валидация: потери 2.5718924307054087 | точность 0.36721991701244816
# ----------
# Эпоха 22/60
# Обучение: потери 1.204118529675712 | точность 0.7331560283687943
# Валидация: потери 2.5851579173918693 | точность 0.3630705394190871
# ----------
# Эпоха 23/60
# Обучение: потери 1.1568239390010564 | точность 0.7526595744680851
# Валидация: потери 2.635987227962863 | точность 0.35684647302904565
# ----------
# Эпоха 24/60
# Обучение: потери 1.122117366589291 | точность 0.7659574468085106
# Валидация: потери 2.555836127650353 | точность 0.3817427385892116
# ----------
# Эпоха 25/60
# Обучение: потери 1.0824088613751908 | точность 0.7712765957446809
# Валидация: потери 2.5923516096607333 | точность 0.37344398340248963
# ----------
# Эпоха 26/60
# Обучение: потери 1.0495833469108797 | точность 0.7872340425531915
# Валидация: потери 2.5006799697875977 | точность 0.3941908713692946
# ----------
# Эпоха 27/60
# Обучение: потери 1.0009584876013473 | точность 0.7907801418439716
# Валидация: потери 2.5487041434934063 | точность 0.3941908713692946
# ----------
# Эпоха 28/60
# Обучение: потери 0.9655711226899859 | точность 0.7969858156028369
# Валидация: потери 2.5521312259858653 | точность 0.38589211618257263
# ----------
# Эпоха 29/60
# Обучение: потери 0.941219043563789 | точность 0.8111702127659575
# Валидация: потери 2.6113659143447876 | точность 0.3900414937759336
# ----------
# Эпоха 30/60
# Обучение: потери 0.9144261840363623 | точность 0.8164893617021276
# Валидация: потери 2.5907561086839244 | точность 0.4004149377593361
# ----------
# Эпоха 31/60
# Обучение: потери 0.888935385875299 | точность 0.8253546099290779
# Валидация: потери 2.6103328504870014 | точность 0.3921161825726141
# ----------
# Эпоха 32/60
# Обучение: потери 0.8578095486466314 | точность 0.8289007092198581
# Валидация: потери 2.575802533857284 | точность 0.3900414937759336
# ----------
# Эпоха 33/60
# Обучение: потери 0.8401274823806655 | точность 0.8368794326241135
# Валидация: потери 2.5819745332964006 | точность 0.3921161825726141
# ----------
# Эпоха 34/60
# Обучение: потери 0.8104057941638249 | точность 0.8430851063829787
# Валидация: потери 2.5161408878141835 | точность 0.3941908713692946
# ----------
# Эпоха 35/60
# Обучение: потери 0.7851125006104859 | точность 0.8546099290780141
# Валидация: потери 2.6573875873319563 | точность 0.3921161825726141
# ----------
# Эпоха 36/60
# Обучение: потери 0.7612370231621702 | точность 0.8625886524822695
# Валидация: потери 2.5742461066092215 | точность 0.3962655601659751
# ----------
# Эпоха 37/60
# Обучение: потери 0.7488161623477936 | точность 0.8572695035460993
# Валидация: потери 2.570739076983544 | точность 0.3941908713692946
# ----------
# Эпоха 38/60
# Обучение: потери 0.7247371535066148 | точность 0.875886524822695
# Валидация: потери 2.6004705852077854 | точность 0.3941908713692946
# ----------
# Эпоха 39/60
# Обучение: потери 0.7083787338834413 | точность 0.8661347517730497
# Валидация: потери 2.6087298200976465 | точность 0.3921161825726141
# ----------
# Эпоха 40/60
# Обучение: потери 0.6944905456522821 | точность 0.874113475177305
# Валидация: потери 2.5635618894330916 | точность 0.3921161825726141
# ----------
# Эпоха 41/60
# Обучение: потери 0.681583734465317 | точность 0.8829787234042553
# Валидация: потери 2.6423620754672634 | точность 0.3879668049792531
# ----------
# Эпоха 42/60
# Обучение: потери 0.6681023873913456 | точность 0.875
# Валидация: потери 2.6146420586493706 | точность 0.3900414937759336
# ----------
# Эпоха 43/60
# Обучение: потери 0.6529452704207998 | точность 0.8882978723404256
# Валидация: потери 2.6196067986949796 | точность 0.3921161825726141
# ----------
# Эпоха 44/60
# Обучение: потери 0.6354673979148059 | точность 0.8953900709219857
# Валидация: потери 2.5902451007596907 | точность 0.3921161825726141
# ----------
# Эпоха 45/60
# Обучение: потери 0.633485004095964 | точность 0.8953900709219857
# Валидация: потери 2.6085435805782193 | точность 0.39834024896265563
# ----------
# Эпоха 46/60
# Обучение: потери 0.6142681068937543 | точность 0.8909574468085106
# Валидация: потери 2.6222856583133822 | точность 0.39834024896265563
# ----------
# Эпоха 47/60
# Обучение: потери 0.6037006991010316 | точность 0.900709219858156
# Валидация: потери 2.5374942210412796 | точность 0.39834024896265563
# ----------
# Эпоха 48/60
# Обучение: потери 0.6032251470105748 | точность 0.899822695035461
# Валидация: потери 2.5891323243418047 | точность 0.4004149377593361
# ----------
# Эпоха 49/60
# Обучение: потери 0.5909062275584315 | точность 0.9060283687943262
# Валидация: потери 2.6021313398115096 | точность 0.4024896265560166
# ----------
# Эпоха 50/60
# Обучение: потери 0.574942044808831 | точность 0.9078014184397163
# Валидация: потери 2.5471283255084867 | точность 0.39834024896265563
# ----------
# Эпоха 51/60
# Обучение: потери 0.5722808833693115 | точность 0.9060283687943262
# Валидация: потери 2.5333795893576836 | точность 0.39834024896265563
# ----------
# Эпоха 52/60
# Обучение: потери 0.5639430679066081 | точность 0.9051418439716312
# Валидация: потери 2.631926571169207 | точность 0.4004149377593361
# ----------
# Эпоха 53/60
# Обучение: потери 0.5610899885355587 | точность 0.9095744680851063
# Валидация: потери 2.563211275685218 | точность 0.3962655601659751
# ----------
# Эпоха 54/60
# Обучение: потери 0.5559005989155299 | точность 0.9104609929078014
# Валидация: потери 2.6383922369249406 | точность 0.4004149377593361
# ----------
# Эпоха 55/60
# Обучение: потери 0.5490320541069541 | точность 0.9193262411347517
# Валидация: потери 2.5724263691133067 | точность 0.3962655601659751
# ----------
# Эпоха 56/60
# Обучение: потери 0.5463251106336083 | точность 0.9202127659574468
# Валидация: потери 2.6405995238211846 | точность 0.3962655601659751
# ----------
# Эпоха 57/60
# Обучение: потери 0.5445500719295421 | точность 0.9175531914893617
# Валидация: потери 2.6327452544243104 | точность 0.4004149377593361
# ----------
# Эпоха 58/60
# Обучение: потери 0.5374492079439298 | точность 0.925531914893617
# Валидация: потери 2.696728806341848 | точность 0.4004149377593361
# ----------
# Эпоха 59/60
# Обучение: потери 0.5419894028717364 | точность 0.9078014184397163
# Валидация: потери 2.5917778322773595 | точность 0.39834024896265563
# ----------
# Эпоха 60/60
# Обучение: потери 0.5371670626418691 | точность 0.9219858156028369
# Валидация: потери 2.6227726513339626 | точность 0.4004149377593361
# ----------

# %% [markdown]
# ### Тестируем работу обученной модели

# %%
import time

test_data  = pd.read_csv('./dataset/test.csv')

texts = list(test_data['groups'])
labels = list(test_data['code'])

predictions = [classifier.predict(t) for t in texts]

report = []     # form report variable

for t, l, p in zip(texts, labels, predictions):
    report.append({
        "real_group": l,
        "predicted_group": p ,
        "isEqual": ("no", "yes")[l == p],
        "groups_set": t
    })

# Экспортируем результаты в CSV файл, поддерживаемый Excel
report_df = pd.DataFrame(report)
report_df.to_csv(f"./reports/report{time.time()}.csv", index_label="id", sep=";", encoding="cp1251")
# Out:
# C:\Users\mrdas\AppData\Local\Temp\ipykernel_23176\3271279555.py:18: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   "isEqual": ("no", "yes")[l == p],

# %% [markdown]
# Выводим таблицу с результатами для сверки

# %%
report_df.head()
# Out:
#    real_group  predicted_group isEqual  \
# 0           1                9      no
# 1           1                1     yes
# 2           1                1     yes
# 3           1                9      no
# 4           1                1     yes
#
#                                           groups_set
# 0  ежик в матане околошкольная математика | борис...
# 1  physics.math.code высшая математика – просто и...
# 2  physics.math.code справедливые мемы про матешу...
# 3  околошкольная математика | борис трушин physic...
# 4  типичный математик code blog physics.math.code...

# %% [markdown]
# ### Получаем метрики

# %%
from sklearn.metrics import precision_recall_fscore_support

precision, recall, f1score = precision_recall_fscore_support(labels, predictions,average='macro', zero_division=0)[:3]

print(f'precision: {precision}, recall: {recall}, f1score: {f1score}')
# Out:
# precision: 0.09115523353853884, recall: 0.1619047619047619, f1score: 0.1021623216699943
